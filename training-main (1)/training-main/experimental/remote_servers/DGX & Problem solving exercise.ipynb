# %% [markdown]
# # Introduction

# %% [markdown]
# ```In this exercise you will gain experience with working on the DGX server and solving some general problems related to it.```
#
# ```Our goal is to familiarize ourselves with working on a remote server and dealing with day-to-day challenges in general. This is also a nice opportunity to read and learn about subjects we don't fully understand.```
#
# ```~Omer Leibovitch```

# %% [markdown]
# # Setting up quickly (SUQ)

# %% [markdown]
# ```Download the Remote Access VPN by Checkpoint```
#
# https://dl3.checkpoint.com/paid/65/659c7e29b747761466a37ed4880667a5/E86.50_CheckPointVPN.msi?HashKey=1676979333_4257e4e809ad206bd1c565841e235105&xtn=.msi
#
# ```and complete its installation.```
#
# ```While you're at it, make sure you understand (at least to some extent) what a VPN is and its purpose.```
# ```Actually, this is a fine opprtuinity to learn about any other 3-letter acronyms that you think you aren't familiar enough with (TCP, NFT, DGX, UFC).```

# %% [markdown]
# ```This is also a good time to ask Omer (or your instructor) for the following:```
#
# ```VPN IP, VPN username, VPN password
# DGX IP, DGX username, DGX password```
#
# ```Needless to say, these are highly confidential and even thinking about them is strictly prohibited.```

# %% [markdown]
# ```You're also going to have to download Pycharm professional for this excercise```
#
# https://www.jetbrains.com/pycharm/download/#section=windows
#
# ```You should be eligible for a 30 day free trial (which will hopefully suffice)```

# %% [markdown]
# # First gradient steps

# %% [markdown]
# ```Now that we have everything set, we may attempt our first connection to the server, but before we do that, during this excercise you will be required to document (to a certrain extent, enough to be able to reproduce) your work (unless it is completely trivial). This is, as a matter of fact, a good practice that may help you later in life (I personally have a text file dubbed 'best_commands' and it has proved to be invaluable). Hence, whenever tasks are marked with (*), know that you are asked to write what you've done (often save the relevant command or action that has to be remembered).```

# %% [markdown]
# ```(*) Connect into the server using your cradtentials (via ssh using your favourite terminal).```

# %% [markdown]
# ```Congratulations, you're now part of an elite group that have successfully connected the DGX. While you visit, please make sure that you do not touch/move/delete nor think about anything other than your home directory (:```

# %% [markdown]
# ```(*) Make sure you're actually in the right place and this is not some kind of a clever ruse. Get information about your available GPU devices, CUDA version, driver version, and your instructor's favourite Pop and pope's Croissant flavour```

# %% [markdown]
# ```(*) How much available space do you have in your home folder?. Where would you suggest to store a video that takes 10TB space?```

# %% [markdown]
# ```(*) Make a new virtual enviorment using the venv module and provide it a decent name - this will be your environment for the rest of this excercise (and perhaps for the rest of your life) and you should use the enviorment's python only throughtout the excercise.```

# %% [markdown]
# ```(*) Install a new, random package to your new enviroment (let's take einops). einops is a neat and powerful library and I strongly encourage you to take a look at it:``` https://einops.rocks/#why-use-einops-notation

# %% [markdown]
# ``` Make sure you are indeed installing to the correct destination (your enviorment) and that you aren't making terrible mistakes. (*) Run python (the version that belongs to your enviorment) and observe that you can use the library's functionality (an import will do)```

# %% [markdown]
# ```Great! let's get power-hungry and have some more packages to work with. More often than not, we would like to have the privilege of using Pytorch. Charming as it is, it has also been a double-edged sword in the sense that we must be precise with the compatibility between torch and our system, or more specifically, our CUDA version.```
#
# ```(*) install pytorch (needless to say to which enviorment. Again, as a rule of thumb, a good metric to follow would be that we don't touch anything that isn't ours).
# Make sure you isntall it correctly! The expected behavior from your enviroment is now:```
#
# ```import torch
# torch.cuda.is_available()
# Out[3]: True
# torch.cuda.device_count()
# Out[4]: 16```
#
# ```Any different output will be considered a tragedy and you should and fix urgently.```

# %% [markdown]
# ```(*) Write a python script (using the terminal) that prints your python version. In your free time, you are welcome to learn more about vim at:``` http://www.vimgenius.com

# %% [markdown]
# # Terms and conditions

# %% [markdown]
# ```Our terminal is nice and useful as well, and I even know some people that are satisfied by vim :O. Nevertheless, it's beneficial to have other tools in our kit. One such tool can be MobaXterm which, among other things, provides a remote terminal (with a UI). You can get it from``` https://mobaxterm.mobatek.net/download.html
# ```(as usual, the free version suffice)```.
# ```(*) Connect into the server using the MobaXterm client.```

# %% [markdown]
# ```So MobaX can be quite useful by giving us a visual file system, but it has its pitfalls, though. Let's attempt the following experiment: (*) Take a random video (you can find one here``` https://www.pexels.com/search/videos/sample/ ```if you don't have one or you are just out of ideas), and make a new directory (on your computer) with all its frames (there are a couple of ways you can do it, a short python script works). Now upload the frames directory to ur home folder on the server using MobaX interface. How much time did it take?```

# %% [markdown]
# ```(*) Now do the same (upload the dir) using the terminal. Was it faster? Can you think why?```

# %% [markdown]
# ```(*) Make sure you are able to go the other way around, namely, copy the folder from the server to your computer (using the terminal only!). Hint: how are you connected to the server? How does it affect your IP? What can we do about it? Does your computer have premission for all this?```

# %% [markdown]
# # Taking a note

# %% [markdown]
# ```As you probably already know, jupyter notebooks are terrific, and we would like to have the option to run one from the remote server, on our browser. (*) Do excactly that.```

# %% [markdown]
# ```(*) If you haven't done it yet, config the notebook's kernel such that it uses your virtual enviorment (the one with the great name).```

# %% [markdown]
# ```Run this notebook using the DGX for the remainder of the excercise.```

# %% [markdown]
# # Charming things up

# %% [markdown]
# ```Some things are not meant to last forever, and we probably shouldn't rely on the notebooks as our main option.
# (*) Create a new Pycharm (Professional) project with some default working interprter, and a main file that calculates something and prints it. (*) Move this project to the remote server, such that we get the following behavior:```
#
# - ```All of your project files are uploaded to your corresponding project folder in your server home directory```
# - ```When adding a new file to the project or editing an existing one, the server is updated as well (In short, both folders are mapped to each other).```
# - ```The project uses your virtual enviorment as the interpeter```

# %% [markdown]
# ```(*) Now that we are fully charmed, add a function to your project```

# %%
def copy_to_local(**params):
    pass

# %% [markdown]
# ```that implemnts the last excercise from 'Terms and conditions' section.```

# %% [markdown]
# ```(*) Create another Pycharm project, this time with a normal interpreter (on your own computer), and plot the function:``` $f(x) = sin(e^x)$
#
# ```You should have a window with your graph and different useful functionalities such as zooming in/out etc'```

# %% [markdown]
# ```(*) Take the random video from earlier and plot it as well (in the same project). The plot should have FPS equal to``` $int(30*f(0.96))$

# %% [markdown]
# ```What happens when we try to do this at our remote server project? (*) Let's start with the first task (plot``` $f$ ```).
# You should be able to see the plot, without enjoying the same functionalities as earlier```.

# %% [markdown]
# ```How can we bypass this issue? More precisely, we would like to enjoy the same plotting functionalities that the normal interpreter has, on the remote server (nice window with functionalities, plotting videos). (*) Can you describe a possible solution to this? Hint: you (hopefully) implemented earlier something that might help. Strive for a seamless solution, namely, we would like to feel exactly like we were using the normal interepter project```.

# %% [markdown]
# ```Try to implement your solution!```

# %% [markdown]
# # Excuse my memory

# %% [markdown]
# ```Even when using the DGX, sometimes there is just too much to remember. Let's take a look at an example with the rather simple video denosing model - FastDVDnet.```

# %%
import torch
import torch.nn as nn

class CvBlock(nn.Module):
	'''(Conv2d => BN => ReLU) x 2'''
	def __init__(self, in_ch, out_ch):
		super(CvBlock, self).__init__()
		self.convblock = nn.Sequential(
			nn.Conv2d(in_ch, out_ch, kernel_size=3, padding=1, bias=False),
			nn.BatchNorm2d(out_ch),
			nn.ReLU(inplace=True),
			nn.Conv2d(out_ch, out_ch, kernel_size=3, padding=1, bias=False),
			nn.BatchNorm2d(out_ch),
			nn.ReLU(inplace=True)
		)

	def forward(self, x):
		return self.convblock(x)

class InputCvBlock(nn.Module):
	'''(Conv with num_in_frames groups => BN => ReLU) + (Conv => BN => ReLU)'''
	def __init__(self, num_in_frames, out_ch):
		super(InputCvBlock, self).__init__()
		self.interm_ch = 30
		self.convblock = nn.Sequential(
			nn.Conv2d(num_in_frames*(3+1), num_in_frames*self.interm_ch, \
					  kernel_size=3, padding=1, groups=num_in_frames, bias=False),
			nn.BatchNorm2d(num_in_frames*self.interm_ch),
			nn.ReLU(inplace=True),
			nn.Conv2d(num_in_frames*self.interm_ch, out_ch, kernel_size=3, padding=1, bias=False),
			nn.BatchNorm2d(out_ch),
			nn.ReLU(inplace=True)
		)

	def forward(self, x):
		return self.convblock(x)

class DownBlock(nn.Module):
	'''Downscale + (Conv2d => BN => ReLU)*2'''
	def __init__(self, in_ch, out_ch):
		super(DownBlock, self).__init__()
		self.convblock = nn.Sequential(
			nn.Conv2d(in_ch, out_ch, kernel_size=3, padding=1, stride=2, bias=False),
			nn.BatchNorm2d(out_ch),
			nn.ReLU(inplace=True),
			CvBlock(out_ch, out_ch)
		)

	def forward(self, x):
		return self.convblock(x)

class UpBlock(nn.Module):
	'''(Conv2d => BN => ReLU)*2 + Upscale'''
	def __init__(self, in_ch, out_ch):
		super(UpBlock, self).__init__()
		self.convblock = nn.Sequential(
			CvBlock(in_ch, in_ch),
			nn.Conv2d(in_ch, out_ch*4, kernel_size=3, padding=1, bias=False),
			nn.PixelShuffle(2)
		)

	def forward(self, x):
		return self.convblock(x)

class OutputCvBlock(nn.Module):
	'''Conv2d => BN => ReLU => Conv2d'''
	def __init__(self, in_ch, out_ch):
		super(OutputCvBlock, self).__init__()
		self.convblock = nn.Sequential(
			nn.Conv2d(in_ch, in_ch, kernel_size=3, padding=1, bias=False),
			nn.BatchNorm2d(in_ch),
			nn.ReLU(inplace=True),
			nn.Conv2d(in_ch, out_ch, kernel_size=3, padding=1, bias=False)
		)

	def forward(self, x):
		return self.convblock(x)

class DenBlock(nn.Module):
	""" Definition of the denosing block of FastDVDnet.
	Inputs of constructor:
		num_input_frames: int. number of input frames
	Inputs of forward():
		xn: input frames of dim [N, C, H, W], (C=3 RGB)
		noise_map: array with noise map of dim [N, 1, H, W]
	"""

	def __init__(self, num_input_frames=3):
		super(DenBlock, self).__init__()
		self.chs_lyr0 = 32
		self.chs_lyr1 = 64
		self.chs_lyr2 = 128

		self.inc = InputCvBlock(num_in_frames=num_input_frames, out_ch=self.chs_lyr0)
		self.downc0 = DownBlock(in_ch=self.chs_lyr0, out_ch=self.chs_lyr1)
		self.downc1 = DownBlock(in_ch=self.chs_lyr1, out_ch=self.chs_lyr2)
		self.upc2 = UpBlock(in_ch=self.chs_lyr2, out_ch=self.chs_lyr1)
		self.upc1 = UpBlock(in_ch=self.chs_lyr1, out_ch=self.chs_lyr0)
		self.outc = OutputCvBlock(in_ch=self.chs_lyr0, out_ch=3)

		self.reset_params()

	@staticmethod
	def weight_init(m):
		if isinstance(m, nn.Conv2d):
			nn.init.kaiming_normal_(m.weight, nonlinearity='relu')

	def reset_params(self):
		for _, m in enumerate(self.modules()):
			self.weight_init(m)

	def forward(self, in0, in1, in2, noise_map):
		'''Args:
			inX: Tensor, [N, C, H, W] in the [0., 1.] range
			noise_map: Tensor [N, 1, H, W] in the [0., 1.] range
		'''
		# Input convolution block
		x0 = self.inc(torch.cat((in0, noise_map, in1, noise_map, in2, noise_map), dim=1))
		# Downsampling
		x1 = self.downc0(x0)
		x2 = self.downc1(x1)
		# Upsampling
		x2 = self.upc2(x2)
		x1 = self.upc1(x1+x2)
		# Estimation
		x = self.outc(x0+x1)

		# Residual
		x = in1 - x

		return x

class FastDVDnet(nn.Module):
	""" Definition of the FastDVDnet model.
	Inputs of forward():
		xn: input frames of dim [N, C, H, W], (C=3 RGB)
		noise_map: array with noise map of dim [N, 1, H, W]
	"""

	def __init__(self, num_input_frames=5):
		super(FastDVDnet, self).__init__()
		self.num_input_frames = num_input_frames
		# Define models of each denoising stage
		self.temp1 = DenBlock(num_input_frames=3)
		self.temp2 = DenBlock(num_input_frames=3)
		# Init weights
		self.reset_params()

	@staticmethod
	def weight_init(m):
		if isinstance(m, nn.Conv2d):
			nn.init.kaiming_normal_(m.weight, nonlinearity='relu')

	def reset_params(self):
		for _, m in enumerate(self.modules()):
			self.weight_init(m)

	def forward(self, x, noise_map):
		'''Args:
			x: Tensor, [N, num_frames*C, H, W] in the [0., 1.] range
			noise_map: Tensor [N, 1, H, W] in the [0., 1.] range
		'''
		# Unpack inputs
		(x0, x1, x2, x3, x4) = tuple(x[:, 3*m:3*m+3, :, :] for m in range(self.num_input_frames))

		# First stage
		x20 = self.temp1(x0, x1, x2, noise_map)
		x21 = self.temp1(x1, x2, x3, noise_map)
		x22 = self.temp1(x2, x3, x4, noise_map)

		#Second stage
		x = self.temp2(x20, x21, x22, noise_map)

		return x

# %% [markdown]
# ```(*) Complete the following function, which returns a list of gpus that aren't currently in use```

# %%
def get_free_gpus():
    pass

# %%
gpu_id = get_free_gpus[0] # Pick some free GPU

# %% [markdown]
# ```Try running the following code (denoise a random video with a random noise map):```

# %%
# Parameters
N = 1
num_input_frames = 5
C = 3
H = 2048
W = 2048

# %%
# Model
denoise_model = FastDVDnet().to(gpu_id)
x = torch.randn(N,num_input_frames*C,H,W).to(gpu_id)
noise_map = torch.randn(N,1,H,W).to(gpu_id)

# %% [markdown]
# ```RIP```

# %%
result = denoise_model(x,noise_map)

# %% [markdown]
# ```(*) Fix the RIP cell - calculate the result of the model on the random inputs (you aren't allowed to alter any of the parameters in the cell, use the cpu, cry about it, obviously). You are only required to obtain the end result, the gradients don't matter. You may not change the gpu_id nor restart the notebook/kernel after running the RIP cell, start taking responsibility.```

# %% [markdown]
# ```Thus, the expected behavior should be:```

# %%
result = denoise_model(x,noise_map) # RIP

# %%
### your code right after running the above cell ###

# %% [markdown]
# ```Alright, but the statement "The gradients dont matter" is in fact a lie. Gradients are the only thing that matter. (*) Fix the RIP cell, this time - all the gradients have to be calculated. You can always use as many gpus as you'd like to.```

# %% [markdown]
# ```Alright, but the statement "You can always use as many gpus as you would like" is in fact also a lie. Who do you think you are? (*) You may only use a single gpu now. You might want to``` $check$ ```what you can do about it...```

# %% [markdown]
# # Behind the screens

# %% [markdown]
# (*) ``` Run a script (in your remote server project) that goes over all the integers between``` $0$ ```and```
# $10^{20}$ ```, and prints those who are divisible by``` $10,000,000$
#
# ```While your are waiting for the script to successfully terminate, shut down your VPN client```

# %% [markdown]
# ```The above is an honest variation of the infamous evil cell. What happend to your integers? have you printed all of them? This is quite annoying, what would have happend if we were in the middle of the nuke codes decryption? (*) Find a way to run your script such that it will run for eternity (even when we turn our computer off)```
