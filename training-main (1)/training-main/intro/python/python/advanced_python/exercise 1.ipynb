# %%
import slowpandas as spd
import re
import math

# %% [markdown]
# $$Score_t=Score_{t-1}+{Ge^{\varphi\pi^2}\cdot \frac{Points_{t}}{\sqrt{Points_{t-1}}}}$$

# %% [markdown]
# # Exercise 01
#     Python Advance Basics

# %% [markdown]
# ## Q1
# You will need to practice string theory.

# %% [markdown]
#     1. Guns&Roses are back. Create a string with 10 back-slashes and print it. FIND AS MANY WAYS POSSIBLE

# %%
temp_string1 = "/"
for i in range(9):
    temp_string1 += "/"
print(temp_string1)

print("".join(["/" for i in range(10)]))
print("/"*10)
# Out:
# //////////
# //////////
# //////////

# %% [markdown]
#     2. Print math.pi with 0,1,2,3,...,15 decimal points.
#         a. 2 LINES OF CODE ONLY
#         b. NO MOD
#         c. NO ROUND

# %%
import math
for i in range(0,16):
    # print((math.pi * (10**i)//1)/(10**i))
    print(f"{math.pi:.{i}f}")
# Out:
# 3
# 3.1
# 3.14
# 3.142
# 3.1416
# 3.14159
# 3.141593
# 3.1415927
# 3.14159265
# 3.141592654
# 3.1415926536
# 3.14159265359
# 3.141592653590
# 3.1415926535898
# 3.14159265358979
# 3.141592653589793

# %% [markdown]
#     3. We must do slow stuff! Call spd.do_slow_stuff.
#         a. Print progress in percentage with 2 decimal points
#         b. NO NEW LINES IN OUTPUT

# %%
import time
import sys

def display_progress(progress):
    percentage = progress * 100
    sys.stdout.write(f"\rProgress: {percentage:.2f}%")
    sys.stdout.flush()

spd.do_slow_stuff(display_progress)
# Out:
# Progress: 100.00%

# %% [markdown]
# ## Q2
# It's women's day! So lets deal with Objects.

# %% [markdown]
#     1. Write a Date class
#         a. you can save only milliseconds as data member
#         b. these operators must work: < > == != + - ...
#         c. you can access fields using a key: date['day'], date['month']

# %%
import math
SECONDS_IN_DAY: int = 86400

class Date:
    def __init__(self, mil):
        self.time = mil
    
    def __add__(self, other):
        return Date(self.time + other.time)
    
    def __eq__(self, other):
        return self.time == other.time
    
    def __lt__(self, other):
        return self.time < other.time
    
    def __gt__(self, other):
        return self.time > other.time

    def __ne__(self, other):
        return self.time != other.time
    
    def __sub__(self, other):
        return Date(self.time - other.time)
    
    def __getitem__(self, key):
        days = self.time // (1000 * SECONDS_IN_DAY)
        year = 1970
        days_in_month = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
        while True:
            days_in_year = 365
            if days < days_in_year:
                break
            days -= days_in_year
            year += 1
        if key == 'year':
            return year
        month = 1
        for days_in_this_month in days_in_month:
            if days < days_in_this_month:
                break
            days -= days_in_this_month
            month += 1
        if key == 'month':
            return month
        day = days + 1
        if key == 'day':
            return day
        if key =='hour':
            seconds = self.time // 1000
            remaining_seconds = seconds % SECONDS_IN_DAY
            hours = remaining_seconds // 3600
            return hours

# %% [markdown]
#     2. Create a list of 240 dates, one date for each hour since 10 days ago.
#         a. ONE LINE OF CODE ALLOWED

# %%
import time
#consts:
current_time_in_mili = int(time.time()*1000)
hour_in_mil = 3600000
day_in_mil = hour_in_mil * 24
#One line of code:
dates = [Date(current_time_in_mili - k*hour_in_mil) for k in range(240)]

# %%
print(dates[1]["hour"])
# Out:
# 9

# %% [markdown]
#     3. Filter your list with these queries:
#         a. Skip a day
#         b. Take only the 8'th day
#         c. Take odd hours only
#
#         *** ONE LINE OF CODE ALLOWED FOR EACH QUERY***

# %%
dates_a = [dates[i] for i in range(0, len(dates), 2)]
dates_b = [d for d in dates if d["day"] == 8]
dates_c = [d for d in dates if d["hour"] % 2 == 0]

# %% [markdown]
# ## Q3
# A top secret agent got his hand on the file 'big_brother.txt'. You will need to help him understand what the file is about.

# %% [markdown]
#     1. Read the file located in the 'data' directory and print it. Is it OK?

# %%
file_path = r"C:\Users\itayf\PycharmProjects\AI_training\training-main (1)\training-main\intro\python\python\advanced_python\resources\data\big_brother.txt"
# Step 1: Read the file as bytes
with open(file_path, "rb") as file:
    byte_data = file.read()

intermediate_decoded = byte_data.decode('utf-8')
final_decoded = intermediate_decoded.encode("ISO-8859-1").decode("utf-8")

# Print the fixed data
print(final_decoded)
# Out:
# 5/17/15, 07:40 - ספי כהן created group “‎‫מחקרי המידע‬‎”
# 5/17/15, 07:40 - You were added
# 11/5/15, 15:07 - עמיאל מייזליש: <Media omitted>
# 11/5/15, 15:23 - ספי כהן: 👍
# 11/7/15, 21:34 - עמיאל מייזליש: https://docs.google.com/spreadsheets/d/1MHAKzza4EpjnVstnIM5STTWeqb59q2q8hMtrYna6zJE/edit#gid=999074856
# 11/7/15, 21:35 - עמיאל מייזליש: interesting dataset, to say the least...
# 11/7/15, 21:47 - גד בנרם: <Media omitted>
# 11/7/15, 21:49 - גד בנרם: בחדר כושר . פיזיקאים יש הסבר?
# 11/7/15, 21:54 - ספי כהן: עמיאל, מגניב לאללה!
# 11/7/15, 21:54 - ספי כהן: תאכלס אפשר להוסיף נתונים נוספים מאבן... 😊
# 11/7/15, 21:55 - Nir Malbin: גד זה פשוט משאבת אוויר
# 11/7/15, 21:55 - Nir Malbin: רואים שיכולות למעלה נמשכות
# 11/7/15, 21:55 - Nir Malbin: הכוסות
# 11/7/15, 21:55 - גד בנרם: אין פה משאבה
# 11/7/15, 21:56 - Nir Malbin: בטח שיש רואים 😤
# 11/7/15, 21:57 - עמיאל מייזליש: גד: חשמל סטטי?
# ספי: קראתי על המאגר בשבת...
# 11/7/15, 21:58 - גד בנרם: נראה לי שחשמל סטאטי
# ...

# %% [markdown]
#     2. That isn't ok. Our intell suggest that this file was taken from the crazy latins which known for decoding things with 'ISO-8859-1'. FIX THE DATA
#         Hint: Is the data unicode? try type('hello') vs type(u'hello')

# %%
print(final_decoded)
# Out:
# 5/17/15, 07:40 - ספי כהן created group “‎‫מחקרי המידע‬‎”
# 5/17/15, 07:40 - You were added
# 11/5/15, 15:07 - עמיאל מייזליש: <Media omitted>
# 11/5/15, 15:23 - ספי כהן: 👍
# 11/7/15, 21:34 - עמיאל מייזליש: https://docs.google.com/spreadsheets/d/1MHAKzza4EpjnVstnIM5STTWeqb59q2q8hMtrYna6zJE/edit#gid=999074856
# 11/7/15, 21:35 - עמיאל מייזליש: interesting dataset, to say the least...
# 11/7/15, 21:47 - גד בנרם: <Media omitted>
# 11/7/15, 21:49 - גד בנרם: בחדר כושר . פיזיקאים יש הסבר?
# 11/7/15, 21:54 - ספי כהן: עמיאל, מגניב לאללה!
# 11/7/15, 21:54 - ספי כהן: תאכלס אפשר להוסיף נתונים נוספים מאבן... 😊
# 11/7/15, 21:55 - Nir Malbin: גד זה פשוט משאבת אוויר
# 11/7/15, 21:55 - Nir Malbin: רואים שיכולות למעלה נמשכות
# 11/7/15, 21:55 - Nir Malbin: הכוסות
# 11/7/15, 21:55 - גד בנרם: אין פה משאבה
# 11/7/15, 21:56 - Nir Malbin: בטח שיש רואים 😤
# 11/7/15, 21:57 - עמיאל מייזליש: גד: חשמל סטטי?
# ספי: קראתי על המאגר בשבת...
# 11/7/15, 21:58 - גד בנרם: נראה לי שחשמל סטאטי
# ...

# %% [markdown]
#     3. A gold mine! Your next task is to turn this data into entities using python classes.
#         Hint: classes are NOT DataFrame - you need User, Message, Date ...

# %%
from datetime import datetime

class DateTime:
    def __init__(self, date_str, time_str):
        self.date = datetime.strptime(date_str, "%m/%d/%y")
        self.time = datetime.strptime(time_str, "%H:%M").time()

    def __str__(self):
        return f"{self.date.strftime('%Y-%m-%d')} {self.time.strftime('%H:%M')}"
    
    def to_dict(self):
        return {"date": self.date.strftime("%Y-%m-%d"), "time": self.time.strftime("%H:%M")}

class User:
    def __init__(self, name):
        self.name = name

    def __str__(self):
        return self.name

    def to_dict(self):
        return {"name": self.name}

class Message:
    def __init__(self, datetime_obj, user, content):
        self.datetime = datetime_obj
        self.user = user
        self.content = content

    def to_dict(self):
        return {
            "datetime": self.datetime.to_dict(),
            "user": self.user.to_dict(),
            "content": self.content,
        }

    def __str__(self):
        return f"[{self.datetime}] {self.user}: {self.content}"

# %% [markdown]
#     4. Classy. Now turn your classes into a SlowDataFrame. Oh! Not before you save them to a file first...
#         *** ALL DATA IN ONE FILE ***

# %%
def parse_line(line):
    try:
        date_time_part, message_part = line.split(" - ", 1)
        date_str, time_str = date_time_part.split(", ")
        user_and_content = message_part.split(": ", 1)
        
        if len(user_and_content) == 2:
            user_name, content = user_and_content
        else:
            user_name = "System"
            content = user_and_content[0]
        
        datetime_obj = DateTime(date_str, time_str)
        user_obj = User(user_name)
        message_obj = Message(datetime_obj, user_obj, content)
        return message_obj
    except ValueError:
        return None

# %%
import json
file_path = r"C:\Users\itayf\PycharmProjects\AI_training\training-main (1)\training-main\intro\python\python\advanced_python\resources\data\big_brother.txt"
def process_file(file_path):
    messages = []

    with open(file_path, "r", encoding="utf-8") as file:
        for line_ in file:
            line = line_.encode("ISO-8859-1").decode("utf-8")
            line = line.strip()
            if line:  # Skip empty lines
                message = parse_line(line)
                if message:
                    messages.append(message.to_dict())

    with open("messages.json", "w", encoding="utf-8") as json_file:
        json.dump(messages, json_file, indent=4)

    return messages
process_file(file_path)
# Out:
# [{'datetime': {'date': '2015-05-17', 'time': '07:40'},
#   'user': {'name': 'System'},
#   'content': 'ספי כהן created group “\u200e\u202bמחקרי המידע\u202c\u200e”'},
#  {'datetime': {'date': '2015-05-17', 'time': '07:40'},
#   'user': {'name': 'System'},
#   'content': 'You were added'},
#  {'datetime': {'date': '2015-11-05', 'time': '15:07'},
#   'user': {'name': 'עמיאל מייזליש'},
#   'content': '<Media omitted>'},
#  {'datetime': {'date': '2015-11-05', 'time': '15:23'},
#   'user': {'name': 'ספי כהן'},
#   'content': '👍'},
#  {'datetime': {'date': '2015-11-07', 'time': '21:34'},
#   'user': {'name': 'עמיאל מייזליש'},
#   'content': 'https://docs.google.com/spreadsheets/d/1MHAKzza4EpjnVstnIM5STTWeqb59q2q8hMtrYna6zJE/edit#gid=999074856'},
#  {'datetime': {'date': '2015-11-07', 'time': '21:35'},
#   'user': {'name': 'עמיאל מייזליש'},
#   'content': 'interesting dataset, to say the least...'},
#  {'datetime': {'date': '2015-11-07', 'time': '21:47'},
#   'user': {'name': 'גד בנרם'},
# ...

# %% [markdown]
#     5. Extract date features: day, month, year, hour, min, sec
#         ONLY USING 'apply' - ONE LINE OF CODE PER FEATURE
#          *** NOTE: slowpandas is quite slow... you MUST output the progress ***

# %%
import timeit
import pandas as pd
with open("messages.json", "r", encoding="utf-8") as json_file:
    data = json.load(json_file)

df = pd.DataFrame(data)
print(df.head())
df["day"] = df["datetime"].apply(lambda dt: int(dt["date"].split("-")[2]))
df["month"] = df["datetime"].apply(lambda dt: int(dt["date"].split("-")[1]))
df["year"] = df["datetime"].apply(lambda dt: int(dt["date"].split("-")[0]))
df["min"] = df["datetime"].apply(lambda dt: int(dt["time"].split(":")[0]))
df["second"] = df["datetime"].apply(lambda dt: int(dt["time"].split(":")[1]))
print(df.head())
# Out:
#                                   datetime                       user  \
# 0  {'date': '2015-05-17', 'time': '07:40'}         {'name': 'System'}
# 1  {'date': '2015-05-17', 'time': '07:40'}         {'name': 'System'}
# 2  {'date': '2015-11-05', 'time': '15:07'}  {'name': 'עמיאל מייזליש'}
# 3  {'date': '2015-11-05', 'time': '15:23'}        {'name': 'ספי כהן'}
# 4  {'date': '2015-11-07', 'time': '21:34'}  {'name': 'עמיאל מייזליש'}
#
#                                              content
# 0            ספי כהן created group “‎‫מחקרי המידע‬‎”
# 1                                     You were added
# 2                                    <Media omitted>
# 3                                                  👍
# 4  https://docs.google.com/spreadsheets/d/1MHAKzz...
#                                   datetime                       user  \
# 0  {'date': '2015-05-17', 'time': '07:40'}         {'name': 'System'}
# 1  {'date': '2015-05-17', 'time': '07:40'}         {'name': 'System'}
# ...

# %% [markdown]
#     6. Plot a graph for each user showing his activity hour-wise (mean)
#         *** ALL GRAPHS IN ONE NOTEBOOK CELL ***

# %%
df["userName"] = df["user"].apply(lambda usr: usr["name"])

# %%
import matplotlib.pyplot as plt

# Extract unique users
users_set = set(df["userName"])  # Assuming "userName" is the correct column name

# Extract hour from timestamp if not already in DataFrame

# Group by user and hour, then compute mean messages per hour
grouped = df.groupby(["userName", "year", "month", "day", "min"]).size().reset_index(name="message_count")
mean_messages_per_hour = grouped.groupby(["userName", "min"])["message_count"].mean().reset_index()

# Plot for each user
for user in users_set:
    user_data = mean_messages_per_hour[mean_messages_per_hour["userName"] == user]

    plt.figure(figsize=(10, 5))
    plt.plot(user_data["min"], user_data["message_count"], marker="o", linestyle="-", label=f"Mean Messages ({user})")
    
    plt.xlabel("Hour of the Day")
    plt.ylabel("Mean Messages per Hour")
    plt.title(f"Mean Messages per Hour for {user}")
    plt.xticks(range(24))  # Ensure x-axis shows all hours
    plt.grid(axis="y", linestyle="--", alpha=0.7)
    plt.legend()
    
    plt.show()

# %% [markdown]
#     7. What is the 10 most common used words for each user?
#         *** NO EXTERNAL LIBS ALLOWED ***

# %%
from collections import Counter
users_words_dict = {k: [] for k in users_set}
for user in users_set:
    print(user)
    print(df.head())
    user_df = df.query("userName == @user")
    content_list = list(user_df["content"])
    users_words_dict[user] += [word for s in content_list for word in s.split(" ")]
user_words_counter_dict = {user: Counter(users_words_dict[user]) for user in users_words_dict.keys()}
for user in user_words_counter_dict.keys():
    print(f"{user}'s 10 most common words are: {user_words_counter_dict[user].most_common(10)}")
# Out:
# Nir Malbin
#                                   datetime                       user  \
# 0  {'date': '2015-05-17', 'time': '07:40'}         {'name': 'System'}
# 1  {'date': '2015-05-17', 'time': '07:40'}         {'name': 'System'}
# 2  {'date': '2015-11-05', 'time': '15:07'}  {'name': 'עמיאל מייזליש'}
# 3  {'date': '2015-11-05', 'time': '15:23'}        {'name': 'ספי כהן'}
# 4  {'date': '2015-11-07', 'time': '21:34'}  {'name': 'עמיאל מייזליש'}
#
#                                              content  day  month  year  min  \
# 0            ספי כהן created group “‎‫מחקרי המידע‬‎”   17      5  2015    7
# 1                                     You were added   17      5  2015    7
# 2                                    <Media omitted>    5     11  2015   15
# 3                                                  👍    5     11  2015   15
# 4  https://docs.google.com/spreadsheets/d/1MHAKzz...    7     11  2015   21
#
#    second       userName
# 0      40         System
# ...
